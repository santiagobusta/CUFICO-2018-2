# %%
import numpy as np
import ROOT
from ROOT import gROOT
from array import array
# Out:
# Welcome to JupyROOT 6.17/01

# %%
Medias=np.array([]) #Esta lista va a almacenar los tiempos de ejecucion medios hallados para cada valor de N, que es la dimensión de la matriz del juego
Maximos=np.array([]) #Esta lista va a almacenar el tiempo maximo de ejecucion hallados para cada valor de N

# %%
Data=open('datos_5.dat','r') #Primero abrimos el archivo de datos

Histograma_5 = ROOT.TH1F( 'h1f', 'Tiempos para n = 5', 13, 0, 3) #Definimos el histograma

data_5 = np.array([]) #Creamos el arreglo de datos

for i in Data: #Aqui almacenamos los valores del archivo datos_5.dat en el arreglo data_5
  data_5=np.append(float(i),data_5)
  Histograma_5.Fill(float(i))

c1 = ROOT.TCanvas( 'c1', 'N = 5', 200, 10, 700, 700 ) #Abrimos un canvas para poder dibujar
c1.SetFillColor(20) #Le damos un poco de estetica al asunto
c1.SetBorderMode(1)
c1.SetBorderSize(5)
c1.SetGrid()

f1 = ROOT.TF1("f1", "gaus", 0, 300); #Definimos aqui la funcion gaussiana con que vamos a hacer el fit de todas los histogramas

x = Histograma_5.GetXaxis(); y = Histograma_5.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_5.Fit("f1","R") #Hacemos el fit para Histograma_5
Histograma_5.Draw() #Y finalmente dibujamos

c1.Update() #y actualizamos el canvas
c1.Draw()

Medias=np.append(Medias,Histograma_5.GetMean()) #Los valores obtenidos para media y maximo son almacenados
Maximos=np.append(Maximos,max(data_5))
# Out:
#  FCN=3.92992 FROM MIGRAD    STATUS=CONVERGED      77 CALLS          78 TOTAL
#                      EDM=1.13316e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     6.85133e+00   2.48569e+00   1.45508e-03   7.03719e-05
#    2  Mean         5.12016e-01   1.19974e-01   1.14530e-04  -9.44627e-04
#    3  Sigma        4.10978e-01   2.24882e-01   9.52166e-05   6.71344e-04

# %%
Data=open('datos_10.dat','r') #En las siguientes celdas hacemos el mismo proceso anterior sin redefinir a f1 

Histograma_10 = ROOT.TH1F( 'h2f', 'Tiempos para n = 10', 15, 0, 10)

data_10 = np.array([])

for i in Data:
  data_10=np.append(float(i),data_10)
  Histograma_10.Fill(float(i))

c2 = ROOT.TCanvas( 'c2', 'N = 10', 200, 10, 700, 700 )
c2.SetFillColor(20)
c2.SetFillColor(20)
c2.SetBorderMode(1)
c2.SetBorderSize(5)
c2.SetGrid()

x = Histograma_10.GetXaxis(); y = Histograma_10.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_10.Fit("f1","R")
Histograma_10.Draw()

c2.Update()
c2.Draw()

Medias=np.append(Medias,Histograma_10.GetMean())
Maximos=np.append(Maximos,max(data_10))
# Out:
#  FCN=6.49514 FROM MIGRAD    STATUS=CONVERGED      91 CALLS          92 TOTAL
#                      EDM=3.87112e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     6.76693e+00   2.35210e+00   1.86626e-03   1.26537e-05
#    2  Mean         2.34254e+00   2.32031e-01   2.90019e-04   1.80643e-04
#    3  Sigma        9.60525e-01   3.29038e-01   6.59465e-05  -4.54445e-04

# %%
Data=open('datos_15.dat','r')

Histograma_15 = ROOT.TH1F( 'h3f', 'Tiempos para N = 15', 7, 0, 20)

data_15 = np.array([])

for i in Data:
  data_15=np.append(float(i),data_15)
  Histograma_15.Fill(float(i))

c3 = ROOT.TCanvas( 'c3', 'N = 15', 200, 10, 700, 700 )
c3.SetFillColor(20)
c3.SetBorderMode(1)
c3.SetBorderSize(5)
c3.SetGrid()

x = Histograma_15.GetXaxis(); y = Histograma_15.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_15.Fit("f1","R")
Histograma_15.Draw()

c3.Update()
c3.Draw()

Medias=np.append(Medias,Histograma_15.GetMean())
Maximos=np.append(Maximos,max(data_15))
# Out:
#  FCN=3.94712 FROM MIGRAD    STATUS=CONVERGED     147 CALLS         148 TOTAL
#                      EDM=2.10525e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.25319e+01   3.22785e+00   2.71918e-03   8.62088e-05
#    2  Mean         4.91688e+00   4.87665e-01   5.20945e-04   1.12187e-03
#    3  Sigma        2.30491e+00   4.08651e-01   3.69659e-05  -1.30363e-02

# %%
Data=open('datos_20.dat','r')

Histograma_20 = ROOT.TH1F( 'h4f', 'Tiempos para N = 20', 9, 0, 25)

data_20 = np.array([])

for i in Data:
  data_20=np.append(float(i),data_20)
  Histograma_20.Fill(float(i))
    
c4 = ROOT.TCanvas( 'c4', 'N = 20', 200, 10, 700, 700 )
c4.SetFillColor(20)
c4.SetBorderMode(1)
c4.SetBorderSize(5)
c4.SetGrid()

x = Histograma_20.GetXaxis(); y = Histograma_20.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_20.Fit("f1","R")
Histograma_20.Draw()

c4.Update()
c4.Draw()

Medias=np.append(Medias,Histograma_20.GetMean())
Maximos=np.append(Maximos,max(data_20))
# Out:
#  FCN=2.96645 FROM MIGRAD    STATUS=CONVERGED      60 CALLS          61 TOTAL
#                      EDM=5.09515e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     5.52463e+00   1.76005e+00   1.05629e-03   4.23091e-04
#    2  Mean         8.75919e+00   1.47219e+00   1.41393e-03  -4.39426e-04
#    3  Sigma        5.99473e+00   2.30025e+00   7.87204e-05   9.63457e-03

# %%
Data=open('datos_25.dat','r')

Histograma_25 = ROOT.TH1F( 'h5f', 'Tiempos para N = 25', 7, 0, 37)

data_25 = np.array([])

for i in Data:
  data_25=np.append(float(i),data_25)
  Histograma_25.Fill(float(i))
    
c5 = ROOT.TCanvas( 'c5', 'N = 25', 200, 10, 700, 700 )
c5.SetFillColor(20)
c5.SetBorderMode(1)
c5.SetBorderSize(5)
c5.SetGrid()

x = Histograma_25.GetXaxis(); y = Histograma_25.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_25.Fit("f1","R")
Histograma_25.Draw()

c5.Update()
c5.Draw()

Medias=np.append(Medias,Histograma_25.GetMean())
Maximos=np.append(Maximos,max(data_25))
# Out:
#  FCN=6.32625 FROM MIGRAD    STATUS=CONVERGED      83 CALLS          84 TOTAL
#                      EDM=1.29495e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     5.64178e+00   2.21480e+00   1.53220e-03   4.21088e-05
#    2  Mean         1.36231e+01   2.41992e+00   3.10041e-03   1.59365e-06
#    3  Sigma        9.65607e+00   4.38103e+00   1.09130e-04   4.14983e-04

# %%
Data=open('datos_30.dat','r')

Histograma_30 = ROOT.TH1F( 'h6f', 'Tiempos para N = 30', 10, 0, 55)

data_30 = np.array([])

for i in Data:
  data_30=np.append(float(i),data_30)
  Histograma_30.Fill(float(i))
    
c6 = ROOT.TCanvas( 'c6', 'N = 30', 200, 10, 700, 700 )
c6.SetFillColor(20)
c6.SetBorderMode(1)
c6.SetBorderSize(5)
c6.SetGrid()

x = Histograma_30.GetXaxis(); y = Histograma_30.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_30.Fit("f1","R")
Histograma_30.Draw()

c6.Update()
c6.Draw()

Medias=np.append(Medias,Histograma_30.GetMean())
Maximos=np.append(Maximos,max(data_30))
# Out:
#  FCN=5.89351 FROM MIGRAD    STATUS=CONVERGED     109 CALLS         110 TOTAL
#                      EDM=7.17638e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     9.37334e+00   3.15684e+00   2.44855e-03  -9.21032e-05
#    2  Mean         1.44464e+01   1.47670e+00   1.77444e-03   8.26674e-04
#    3  Sigma        6.01211e+00   2.11584e+00   6.38273e-05   2.89198e-03

# %%
Data=open('datos_35.dat','r')

Histograma_35 = ROOT.TH1F( 'h7f', 'Tiempos para N = 35', 12, 0, 150)

data_35 = np.array([])

for i in Data:
  data_35=np.append(float(i),data_35)
  Histograma_35.Fill(float(i))
    
c7 = ROOT.TCanvas( 'c7', 'N = 35', 200, 10, 700, 700 )
c7.SetFillColor(20)
c7.SetBorderMode(1)
c7.SetBorderSize(5)
c7.SetGrid()

x = Histograma_35.GetXaxis(); y = Histograma_35.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_35.Fit("f1","R")
Histograma_35.Draw()

c7.Update()
c7.Draw()

Medias=np.append(Medias,Histograma_35.GetMean())
Maximos=np.append(Maximos,max(data_35))
# Out:
#  FCN=5.60056 FROM MIGRAD    STATUS=CONVERGED      92 CALLS          93 TOTAL
#                      EDM=6.425e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     8.64158e+00   2.41649e+00   2.19627e-03  -4.33145e-04
#    2  Mean         3.26672e+01   3.35702e+00   3.75281e-03   2.14634e-04
#    3  Sigma        1.42194e+01   2.91789e+00   3.99021e-05  -1.12379e-02

# %%
Data=open('datos_40.dat','r')

Histograma_40 = ROOT.TH1F( 'h8f', 'Tiempos para N = 40', 17, 0, 150)

data_40 = np.array([])

for i in Data:
  data_40=np.append(float(i),data_40)
  Histograma_40.Fill(float(i))
        
c8 = ROOT.TCanvas( 'c8', 'N = 40', 200, 10, 700, 700 )
c8.SetFillColor(20)
c8.SetBorderMode(1)
c8.SetBorderSize(5)
c8.SetGrid()

x = Histograma_40.GetXaxis(); y = Histograma_40.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_40.Fit("f1","R")
Histograma_40.Draw()

c8.Update()
c8.Draw()

Medias=np.append(Medias,Histograma_40.GetMean())
Maximos=np.append(Maximos,max(data_40))
# Out:
#  FCN=7.5683 FROM MIGRAD    STATUS=CONVERGED      68 CALLS          69 TOTAL
#                      EDM=1.78345e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     4.17012e+00   1.15583e+00   1.25700e-03   5.59915e-05
#    2  Mean         4.60586e+01   5.36590e+00   7.65449e-03  -2.82486e-05
#    3  Sigma        2.07069e+01   5.56061e+00   8.15012e-05   2.12927e-03

# %%
Data=open('datos_45.dat','r')

Histograma_45 = ROOT.TH1F( 'h9f', 'Tiempos para N = 45', 15, 0, 125)

data_45 = np.array([])

for i in Data:
  data_45=np.append(float(i),data_45)
  Histograma_45.Fill(float(i))
        
c9 = ROOT.TCanvas( 'c9', 'N = 45', 200, 10, 700, 700 )
c9.SetFillColor(20)
c9.SetBorderMode(1)
c9.SetBorderSize(5)
c9.SetGrid()

x = Histograma_45.GetXaxis(); y = Histograma_45.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_45.Fit("f1","R")
Histograma_45.Draw()

c9.Update()
c9.Draw()

Medias=np.append(Medias,Histograma_45.GetMean())
Maximos=np.append(Maximos,max(data_45))
# Out:
#  FCN=6.00126 FROM MIGRAD    STATUS=CONVERGED      67 CALLS          68 TOTAL
#                      EDM=1.11532e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     5.13232e+00   1.57257e+00   1.35141e-03  -1.16654e-04
#    2  Mean         5.00872e+01   5.72144e+00   7.01906e-03   8.48628e-06
#    3  Sigma        2.44284e+01   6.76053e+00   6.98751e-05  -7.23276e-03

# %%
Data=open('datos_50.dat','r')

Histograma_50 = ROOT.TH1F( 'h10f', 'Tiempos para N = 50', 9, 0, 275)

data_50 = np.array([])

for i in Data:
  data_50=np.append(float(i),data_50)
  Histograma_50.Fill(float(i))
        
c10 = ROOT.TCanvas( 'c10', 'N = 50', 200, 10, 700, 700 )
c10.SetFillColor(20)
c10.SetBorderMode(1)
c10.SetBorderSize(5)
c10.SetGrid()

x = Histograma_50.GetXaxis(); y = Histograma_50.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_50.Fit("f1","R")
Histograma_50.Draw()

c10.Update()
c10.Draw()

Medias=np.append(Medias,Histograma_50.GetMean())
Maximos=np.append(Maximos,max(data_50))
# Out:
#  FCN=9.63001 FROM MIGRAD    STATUS=CONVERGED      94 CALLS          95 TOTAL
#                      EDM=6.48613e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     8.40090e+00   2.81802e+00   2.96325e-03   2.19592e-04
#    2  Mean         6.82424e+01   9.91189e+00   1.08338e-02  -7.58762e-05
#    3  Sigma        2.98073e+01   7.78465e+00   5.14467e-05   1.48076e-03

# %%
Data=open('datos_55.dat','r')

Histograma_55 = ROOT.TH1F( 'h11f', 'Tiempos para N = 55', 7, 0, 260)

data_55 = np.array([])

for i in Data:
  data_55=np.append(float(i),data_55)
  Histograma_55.Fill(float(i))
        
c11 = ROOT.TCanvas( 'c11', 'N = 55', 200, 10, 700, 700 )
c11.SetFillColor(20)
c11.SetBorderMode(1)
c11.SetBorderSize(5)
c11.SetGridx()
c11.SetGridy()

x = Histograma_55.GetXaxis(); y = Histograma_55.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_55.Fit("f1","R")
Histograma_55.Draw()

c11.Update()
c11.Draw()

Medias=np.append(Medias,Histograma_55.GetMean())
Maximos=np.append(Maximos,max(data_55))
# Out:
#  FCN=5.04349 FROM MIGRAD    STATUS=CONVERGED      80 CALLS          81 TOTAL
#                      EDM=2.52958e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     7.24618e+00   2.40621e+00   1.74038e-03   3.04024e-05
#    2  Mean         5.76081e+01   2.60674e+01   1.78070e-02   4.30229e-06
#    3  Sigma        6.16014e+01   3.14821e+01   8.53224e-05   7.08637e-04

# %%
Data=open('datos_60.dat','r')

Histograma_60 = ROOT.TH1F( 'h12f', 'Tiempos para N = 60', 10, 0, 280)

data_60 = np.array([])

for i in Data:
  data_60=np.append(float(i),data_60)
  Histograma_60.Fill(float(i))
        
c12 = ROOT.TCanvas( 'c12', 'N = 60', 200, 10, 700, 700 )
c12.SetFillColor(20)
c12.SetBorderMode(1)
c12.SetBorderSize(5)
c12.SetGrid()

x = Histograma_60.GetXaxis(); y = Histograma_60.GetYaxis()
x.SetTitle("Tiempo [s]"); y.SetTitle("Frecuencia")
Histograma_60.Fit("f1","R")
Histograma_60.Draw()

c12.Update()
c12.Draw()

Medias=np.append(Medias,Histograma_60.GetMean())
Maximos=np.append(Maximos,max(data_60))
# Out:
#  FCN=4.25071 FROM MIGRAD    STATUS=CONVERGED      70 CALLS          71 TOTAL
#                      EDM=4.62495e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     6.33671e+00   1.63651e+00   1.39345e-03  -3.60599e-04
#    2  Mean         9.29711e+01   1.04426e+01   1.13836e-02   6.78552e-05
#    3  Sigma        4.69286e+01   9.35068e+00   4.85130e-05  -1.78124e-02

# %%
print Medias #Tiempos medios para cada n
# Out:
# [   0.68526307    2.9489961     6.23787103    9.85110276   15.33213667
#    19.46257967   41.8022       53.483475     51.42068      87.55815667
#    91.6054      107.36664333]

# %%
print Maximos #Tiempos maximos para cada n
# Out:
# [   2.21605    9.05755   29.6163    25.6473    36.0178    52.0508   148.346
#   146.13     122.251    273.584    257.704    276.564  ]

# %%
c13 = ROOT.TCanvas( 'c13', 'Tiempo medio vs N', 200, 10, 700, 500)
c13.SetGrid()

sq = ROOT.TF1("sq", "[0]*x**2", 1, 60) #De estos datos hacemos un fit de la forma ax**2
sq.SetParameter(0, 1)

n = array('d', range(5,65,5))
gr = ROOT.TGraph(12, n, Medias)
gr.SetTitle("Tiempo medio vs N")
gr.SetMarkerStyle( 21 )
x=gr.GetXaxis(); y = gr.GetYaxis()
x.SetTitle("N"); y.SetTitle("Tiempo medio [s]")
gr.Fit("sq", "R")
gr.Draw()

c13.Update()
c13.Draw()
# Out:
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =      366.433
# NDf                       =           11
# Edm                       =  1.47537e-22
# NCalls                    =           15
# p0                        =     0.030471   +/-   0.000936981

# %%
c14 = ROOT.TCanvas( 'c14', 'Tiempo maximo vs N', 200, 10, 700, 500)
c14.SetGrid()

gr = ROOT.TGraph(12, n, Maximos)
gr.SetTitle("Tiempo maximo vs N")
gr.SetMarkerStyle( 21 )
x=gr.GetXaxis(); y = gr.GetYaxis()
x.SetTitle("N"); y.SetTitle("Tiempo maximo [s]")
gr.Fit("sq", "R")
gr.Draw()

c14.Update()
c14.Draw()
# Out:
# ****************************************
# Minimizer is Minuit / Migrad
# Chi2                      =      10207.6
# NDf                       =           11
# Edm                       =  9.43137e-15
# NCalls                    =           13
# p0                        =    0.0845851   +/-   0.00494534
