# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=15', 60,0, 0.1)

# %%
Data=[0.024, 0.023, 0.039, 0.025, 0.013, 0.031, 0.025, 0.031, 0.048, 0.032, 0.041, 0.017, 0.033, 0.011, 0.042, 0.024, 0.046, 0.025, 0.060, 0.039, 0.013, 0.013, 0.030, 0.044, 0.061, 0.016, 0.011, 0.024, 0.021, 0.029, 0.025, 0.032, 0.030, 0.044, 0.015, 0.021, 0.020, 0.039, 0.026, 0.019, 0.045, 0.050, 0.008, 0.024, 0.023, 0.021, 0.022, 0.025, 0.039, 0.010, 0.021, 0.027, 0.029, 0.014, 0.025, 0.014, 0.031, 0.046, 0.012, 0.044, 0.066]
for i in Data:
  OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=15', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.1);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=16.48 FROM MIGRAD    STATUS=CONVERGED      92 CALLS          93 TOTAL
#                      EDM=1.28056e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.24769e+00   5.12433e-01   6.88004e-04   7.82897e-04
#    2  Mean         2.91344e-02   4.63305e-03   9.35098e-06  -3.42334e-01
#    3  Sigma        2.04608e-02   7.80744e-03   2.18859e-04   1.66397e-03
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
