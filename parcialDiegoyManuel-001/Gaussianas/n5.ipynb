# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=5', 60,0, 0.03)

# %%
Data=[0.007, 0.011, 0.007, 0.012, 0.013, 0.016, 0.014, 0.025, 0.010, 0.019, 0.013, 0.016, 0.002, 0.012, 0.006, 0.010, 0.006, 0.014, 0.013, 0.006, 0.013, 0.006, 0.016, 0.020, 0.013, 0.010, 0.011, 0.020, 0.013, 0.008, 0.008, 0.007, 0.012, 0.007, 0.011, 0.013, 0.011, 0.021, 0.011, 0.010, 0.018, 0.021, 0.017, 0.002, 0.011, 0.009, 0.015, 0.013, 0.007, 0.008, 0.013, 0.011, 0.015, 0.023, 0.013, 0.014, 0.022, 0.019, 0.004, 0.010, 0.013]
for i in Data:
  OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=5', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.03);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=18.7148 FROM MIGRAD    STATUS=CONVERGED     103 CALLS         104 TOTAL
#                      EDM=9.09612e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.80028e+00   6.42114e-01   9.33615e-04  -4.13520e-06
#    2  Mean         1.12568e-02   1.84433e-03   3.51449e-06   1.21966e-02
#    3  Sigma        7.63336e-03   2.66340e-03   1.98408e-04   2.99792e-04
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
