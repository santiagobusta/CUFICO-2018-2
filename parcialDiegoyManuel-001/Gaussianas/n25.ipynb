# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=25', 60,0, 0.1)

# %%
Data=[ 0.024, 0.022, 0.035, 0.039, 0.032, 0.020, 0.040, 0.040, 0.024, 0.033, 0.046, 0.042, 0.030, 0.024, 0.027, 0.054, 0.043, 0.051, 0.042, 0.046, 0.043, 0.045, 0.058, 0.031, 0.010, 0.040, 0.036, 0.033, 0.040, 0.033, 0.081, 0.024, 0.081, 0.034, 0.062, 0.040, 0.029, 0.069, 0.030, 0.016, 0.045, 0.041, 0.029, 0.049, 0.039, 0.025, 0.044, 0.029, 0.028, 0.026, 0.028, 0.042, 0.041, 0.025, 0.029, 0.008, 0.029, 0.031, 0.026, 0.034, 0.022 ]
for i in Data:
  OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=25', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.1);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=14.3296 FROM MIGRAD    STATUS=CONVERGED      78 CALLS          79 TOTAL
#                      EDM=1.50822e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.90687e+00   6.20994e-01   8.13484e-04   1.69260e-04
#    2  Mean         3.36336e-02   2.90701e-03   5.54649e-06   5.41977e-02
#    3  Sigma        1.49760e-02   4.06807e-03   1.23465e-04   1.25727e-03
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
