# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=35', 60,0, 0.15)

# %%
Data=[ 0.028, 0.049, 0.052, 0.051, 0.042, 0.031, 0.027, 0.027, 0.029, 0.047, 0.033, 0.043, 0.034, 0.033, 0.015, 0.040, 0.047, 0.022, 0.023, 0.014, 0.062, 0.030, 0.036, 0.032, 0.100, 0.046, 0.035, 0.037, 0.161, 0.092, 0.093, 0.083, 0.071, 0.073, 0.081, 0.066, 0.069, 0.035, 0.134, 0.050, 0.090, 0.076, 0.042, 0.069, 0.093, 0.063, 0.066, 0.059, 0.026, 0.067, 0.024, 0.103, 0.079, 0.048, 0.107, 0.062, 0.033, 0.054, 0.099, 0.081, 0.082]
for i in Data:
    OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=35', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.15);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=11.9653 FROM MIGRAD    STATUS=CONVERGED     128 CALLS         129 TOTAL
#                      EDM=4.88799e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.66455e+00   3.19429e-01   4.22247e-04  -7.37383e-04
#    2  Mean         3.97407e-02   3.47053e-02   3.47575e-05   6.16989e-03
#    3  Sigma        6.63947e-02   5.10062e-02   4.09508e-04   1.49624e-04
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
