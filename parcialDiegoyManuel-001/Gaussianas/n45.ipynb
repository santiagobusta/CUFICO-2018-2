# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=45', 60,0, 0.2)

# %%
Data=[  0.048, 0.025, 0.040, 0.018, 0.067, 0.034, 0.041, 0.049, 0.085, 0.071, 0.059, 0.021, 0.022, 0.065, 0.028, 0.055, 0.053, 0.036, 0.026, 0.025, 0.022, 0.033, 0.043, 0.026, 0.040, 0.023, 0.038, 0.034, 0.066, 0.047, 0.012, 0.069, 0.002, 0.028, 0.061, 0.050, 0.040, 0.038, 0.050, 0.018, 0.021, 0.084, 0.065, 0.007, 0.037, 0.028, 0.017, 0.050, 0.063, 0.051, 0.019, 0.027, 0.023, 0.045, 0.044, 0.023, 0.052, 0.062, 0.043, 0.035, 0.024]
for i in Data:
    OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=45', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.2);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=18.9277 FROM MIGRAD    STATUS=CONVERGED      96 CALLS          97 TOTAL
#                      EDM=1.79502e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.63456e+00   6.03405e-01   8.85051e-04  -7.96689e-04
#    2  Mean         3.81340e-02   6.59069e-03   1.36935e-05   3.20796e-02
#    3  Sigma        2.75786e-02   9.81277e-03   2.18765e-04   2.07191e-04
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
