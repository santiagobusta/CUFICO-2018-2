# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=10', 60,0, 0.04)

# %%
Data=[0.013, 0.017, 0.024, 0.021, 0.020, 0.007, 0.021, 0.024, 0.025, 0.016, 0.022, 0.026, 0.015, 0.014, 0.054, 0.007, 0.026, 0.005, 0.015, 0.039, 0.018, 0.020, 0.008, 0.024, 0.014, 0.017, 0.028, 0.023, 0.012, 0.009, 0.020, 0.022, 0.028, 0.009, 0.012, 0.036, 0.015, 0.009, 0.021, 0.014, 0.015, 0.023, 0.020, 0.013, 0.010, 0.023, 0.020, 0.035, 0.032, 0.018, 0.016, 0.021, 0.061, 0.008, 0.011, 0.033, 0.018, 0.016, 0.020, 0.018, 0.014]
for i in Data:
  OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=10', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.04);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=9.43489 FROM MIGRAD    STATUS=CONVERGED      86 CALLS          87 TOTAL
#                      EDM=1.70964e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.65320e+00   5.39768e-01   5.94355e-04  -1.29262e-05
#    2  Mean         1.92159e-02   2.05849e-03   3.22513e-06   8.47708e-03
#    3  Sigma        1.04102e-02   2.87064e-03   1.22765e-04  -7.41378e-05
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
