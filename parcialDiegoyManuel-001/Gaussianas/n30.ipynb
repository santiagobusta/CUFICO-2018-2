# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=30', 60,0, 0.1)

# %%
Data=[ 0.056, 0.043, 0.038, 0.011, 0.037, 0.047, 0.034, 0.025, 0.023, 0.022, 0.050, 0.021, 0.040, 0.038, 0.024, 0.030, 0.033, 0.047, 0.025, 0.042, 0.023, 0.044, 0.018, 0.073, 0.019, 0.060, 0.049, 0.033, 0.031, 0.026, 0.022, 0.075, 0.021, 0.019, 0.015, 0.024, 0.026, 0.035, 0.027, 0.028, 0.041, 0.015, 0.028, 0.059, 0.029, 0.032, 0.046, 0.059, 0.036, 0.043, 0.063, 0.014, 0.041, 0.020, 0.068, 0.010, 0.011, 0.015, 0.035, 0.026, 0.016]
for i in Data:
    OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=30', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.1);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=13.5697 FROM MIGRAD    STATUS=CONVERGED     120 CALLS         121 TOTAL
#                      EDM=4.30808e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.75284e+00   3.20239e-01   4.74374e-04   2.77002e-03
#    2  Mean         2.42518e-02   2.26248e-02   2.22151e-05   7.38772e-02
#    3  Sigma        3.96239e-02   2.90565e-02   4.05458e-04   3.93231e-03
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
