# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=50', 60,0, 0.2)

# %%
Data=[ 0.037, 0.050, 0.026, 0.066, 0.047, 0.045, 0.056, 0.038, 0.031, 0.012, 0.067, 0.052, 0.096, 0.042, 0.064, 0.052, 0.023, 0.042, 0.049, 0.029, 0.058, 0.032, 0.017, 0.026, 0.026, 0.032, 0.039, 0.036, 0.030, 0.044, 0.006, 0.034, 0.032, 0.036, 0.046, 0.042, 0.124, 0.103, 0.204, 0.102, 0.088, 0.050, 0.130, 0.062, 0.088, 0.181, 0.122, 0.013, 0.151, 0.029, 0.159, 0.079, 0.032, 0.069, 0.008, 0.094, 0.018, 0.052, 0.043, 0.047, 0.064 ]
for i in Data:
    OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=50', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.2);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=13.2286 FROM MIGRAD    STATUS=CONVERGED     114 CALLS         115 TOTAL
#                      EDM=5.73129e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.86375e+00   3.40546e-01   5.02168e-04   4.35788e-04
#    2  Mean         4.93302e-02   3.42362e-02   4.69277e-05   9.74709e-03
#    3  Sigma        8.45504e-02   4.72159e-02   3.52291e-04   2.58265e-04
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
