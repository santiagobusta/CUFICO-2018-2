# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=60', 60,0, 0.2)

# %%
Data=[ 0.126, 0.020, 0.048, 0.066, 0.044, 0.051, 0.031, 0.034, 0.066, 0.069, 0.028, 0.044, 0.042, 0.038, 0.031, 0.042, 0.026, 0.053, 0.049, 0.079, 0.045, 0.014, 0.029, 0.040, 0.058, 0.032, 0.069, 0.052, 0.043, 0.060, 0.043, 0.037, 0.123, 0.029, 0.016, 0.050, 0.034, 0.045, 0.052, 0.028, 0.046, 0.023, 0.035, 0.057, 0.037, 0.063, 0.058, 0.050, 0.057, 0.032, 0.051, 0.025, 0.084, 0.023, 0.019, 0.031, 0.050, 0.040, 0.060, 0.040, 0.030 ]
for i in Data:
    OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=60', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.2);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=12.9588 FROM MIGRAD    STATUS=CONVERGED      78 CALLS          79 TOTAL
#                      EDM=6.31555e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.89732e+00   8.35612e-01   1.02555e-03   1.49624e-03
#    2  Mean         4.08954e-02   3.95116e-03   7.12820e-06   7.73139e-02
#    3  Sigma        2.04524e-02   5.69465e-03   1.12037e-04   1.80723e-02
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
