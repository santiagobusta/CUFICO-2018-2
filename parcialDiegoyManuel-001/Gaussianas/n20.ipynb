# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=20', 60,0, 0.1)

# %%
Data=[0.011, 0.035, 0.047, 0.042, 0.022, 0.025, 0.059, 0.016, 0.033, 0.032, 0.021, 0.017, 0.012, 0.083, 0.016, 0.059, 0.020, 0.026, 0.058, 0.014, 0.088, 0.057, 0.030, 0.031, 0.009, 0.025, 0.018, 0.016, 0.032, 0.040, 0.047, 0.022, 0.010, 0.030, 0.043, 0.028, 0.015, 0.060, 0.069, 0.063, 0.013, 0.008, 0.082, 0.014, 0.010, 0.035, 0.060, 0.017, 0.033, 0.025, 0.029, 0.039, 0.039, 0.032, 0.020, 0.032, 0.051, 0.028, 0.016, 0.031, 0.007]
for i in Data:
  OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=20', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.1);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=11.1996 FROM MIGRAD    STATUS=CONVERGED     127 CALLS         128 TOTAL
#                      EDM=2.01644e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.15825e+00   3.95596e-01   5.21604e-04   9.79752e-05
#    2  Mean         2.77640e-02   2.19864e-02   2.39529e-05  -3.33217e-03
#    3  Sigma        4.46710e-02   3.21702e-02   3.69642e-04  -5.79278e-05
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
