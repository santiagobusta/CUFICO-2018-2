# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=55', 60,0, 0.2)

# %%
Data=[ 0.022, 0.067, 0.021, 0.025, 0.035, 0.050, 0.030, 0.039, 0.062, 0.051, 0.026, 0.065, 0.077, 0.025, 0.035, 0.043, 0.061, 0.022, 0.039, 0.036, 0.037, 0.037, 0.032, 0.049, 0.042, 0.036, 0.058, 0.026, 0.040, 0.086, 0.027, 0.063, 0.053, 0.026, 0.041, 0.029, 0.103, 0.064, 0.039, 0.067, 0.032, 0.084, 0.038, 0.017, 0.020, 0.055, 0.073, 0.047, 0.023, 0.086, 0.123, 0.031, 0.024, 0.044, 0.037, 0.055, 0.016, 0.018, 0.122, 0.015, 0.012 ]
for i in Data:
    OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=55', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.2);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=15.8235 FROM MIGRAD    STATUS=CONVERGED     154 CALLS         155 TOTAL
#                      EDM=7.99973e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.31401e+00   5.10703e-01   6.89671e-04   7.43725e-04
#    2  Mean         1.95262e-02   6.76037e-02   3.79094e-05   1.94078e-02
#    3  Sigma        6.73185e-02   7.59693e-02   4.58730e-04   1.33530e-03
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
