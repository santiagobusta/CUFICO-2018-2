# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.14/06

# %%
OneSimpleHisto = ROOT.TH1F( 'Datos', 'Mapa con n=40', 60,0, 0.2)

# %%
Data=[ 0.083, 0.141, 0.082, 0.097, 0.013, 0.083, 0.032, 0.065, 0.059, 0.036, 0.132, 0.029, 0.068, 0.060, 0.041, 0.096, 0.067, 0.023, 0.048, 0.034, 0.026, 0.052, 0.099, 0.054, 0.010, 0.025, 0.046, 0.033, 0.048, 0.027, 0.042, 0.020, 0.034, 0.022, 0.033, 0.048, 0.063, 0.033, 0.026, 0.037, 0.055, 0.042, 0.054, 0.017, 0.052, 0.041, 0.020, 0.039, 0.032, 0.021, 0.018, 0.019, 0.020, 0.031, 0.040, 0.023, 0.035, 0.045, 0.067, 0.060, 0.079]
for i in Data:
    OneSimpleHisto.Fill(i)

# %%
c1 = ROOT.TCanvas( 'c1', 'Mapa con n=40', 200, 10, 700, 900 )
c1.SetFillColor( 18 )
OneSimpleHisto.Draw()
c1.Update()
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()

# %%
f1 = ROOT.TF1("f1", "gaus", 0, 0.2);
OneSimpleHisto.Fit("f1","R")
# Out:
#  FCN=14.9559 FROM MIGRAD    STATUS=CONVERGED     132 CALLS         133 TOTAL
#                      EDM=2.02301e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.27530e+00   4.99771e-01   6.53994e-04  -4.87879e-04
#    2  Mean         3.99621e-02   1.84762e-02   3.15406e-05  -4.58811e-03
#    3  Sigma        5.50307e-02   3.77571e-02   4.23634e-04  -2.66194e-04
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
OneSimpleHisto.Draw()
c1.Update()
gROOT.GetListOfCanvases().Draw()
